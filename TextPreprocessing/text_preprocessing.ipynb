# %%
import pandas as pd
import re

# %%
df = pd.read_csv("data/movies_data.csv")
df.sample(5)
# Out:
#                    title         genre language  \
# 5662       The Charlatan  Crime, Drama       hu
# 9943  Lykkens musikanter        Comedy       da
# 9838          Mrs. Recto         Drama       tl
# 6524    Azrail Peşimizde     Adventure       tr
# 7727             Shabnam     Adventure       hi
#
#                                                   casts  \
# 5662  Gyula Csortos (Tordai Dezsõ medikus), Tivadar ...
# 9943  Dirch Passer (Elevatorfører Gogol), Ove Sprogø...
# 9838              Regine Velasquez (), Elmo Magalona ()
# 6524  İrfan Atasoy (), Eva Bender (), Gönül Hancı ()...
# 7727  Mehmood (Khan Mustafa/Zingarro), L. Vijayalaks...
#
#                                             description release_date
# 5662                                                NaN   1917-09-10
# 9943  Villa Orfeus is a peculiar old house that has ...   1962-02-19
# 9838  Clara is a Recto shop owner who peddles fake c...   2010-09-03
# 6524  Irfan is an engineer working in the Highways D...   1971-01-01
# 7727  A faithful retainer tries to foil the plot to ...   1964-01-01

# %%
df = df.dropna()

# %% [markdown]
# ## 1. Lowercasing

# %%
df['description'] = df['description'].str.lower()
df.sample(5)
# Out:
#                           title                     genre language  \
# 1519  The Count of Monte Cristo  Adventure, Action, Drama       fr
# 920                       Franz            Drama, History       cs
# 7525                       Lamb                     Drama       en
# 2356          An American Crime      Crime, Drama, Horror       en
# 5392                   Heatwave                     Drama       en
#
#                                                   casts  \
# 1519  Pierre Niney (Edmond Dantès / The Count of Mon...
# 920   Idan Weiss (Franz Kafka), Peter Kurth (Hermann...
# 7525  Liam Neeson (Michael Lamb), Hugh O'Conor (Owen...
# 2356  Elliot Page (Sylvia Likens), Catherine Keener ...
# 5392  Judy Davis (Kate Dean), Richard Moir (Stephen ...
#
#                                             description release_date
# 1519  edmond dantès becomes the target of a sinister...   2024-06-28
# 920   conceived as a kaleidoscopic mosaic, the film ...   2025-09-25
# 7525  michael lamb is a father questioning his calli...   1986-10-10
# 2356  the true story of suburban housewife gertrude ...   2007-07-27
# 5392  during a christmas heatwave, a community activ...   1982-03-08

# %% [markdown]
# ## 2. Removing HTML Tags

# %%
## no html tags present

word = "The <title> element specifies a title for the HTML page (which is shown in the browser's title bar or in the page's tab)"

pattern = re.compile("<[^>]+>")
pattern.sub("",word)
# Out:
# "The  element specifies a title for the HTML page (which is shown in the browser's title bar or in the page's tab)"

# %% [markdown]
# ## 3. Removing URLs

# %%
## no html tags present

word = "Check https://openai.com and www.google.com now!"

pattern = re.compile(r"(?:https?://|www\.)[^\s]+")
pattern.sub("",word)
# Out:
# 'Check  and  now!'

# %% [markdown]
# ## 4. Removing Punctuation

# %% [markdown]
# ### Using for loop

# %%
import string

# %%
df['description'][0]
# Out:
# "estranged half-brothers jonny and james reunite after their father's mysterious death. as they search for the truth, buried secrets reveal a conspiracy threatening to tear their family apart."

# %%
puctuations = string.punctuation
puctuations
# Out:
# '!"#$%&\'()*+,-./:;<=>?@[\\]^_`{|}~'

# %%
# will take more time

def remove_puctuations(word):
    for c in puctuations:
        word = word.replace(c,"")
    return word

# %%
remove_puctuations(df['description'][2])
# Out:
# 'after cracking the biggest case in zootopias history rookie cops judy hopps and nick wilde find themselves on the twisting trail of a great mystery when gary desnake arrives and turns the animal metropolis upside down to crack the case judy and nick must go undercover to unexpected new parts of town where their growing partnership is tested like never before'

# %%
# df['description'] = df['description'].apply(remove_puctuations)

# %%
df.sample(5)
# Out:
#                    title                                      genre language  \
# 2681           Get Santa                             Comedy, Family       en
# 5908           Saltwater  TV Movie, Science Fiction, Action, Horror       en
# 9559  The Tokyo Siblings                                      Drama       ja
# 2658      The Trespasser                                      Drama       en
# 5238                Pals                                      Drama       es
#
#                                                   casts  \
# 2681  Jim Broadbent (Santa Claus), Rafe Spall (Steve...
# 5908  Rachele Brooke Smith (Gina), Jeff Fahey (Rottg...
# 9559  Yuriko Hirooka (Yoshiko Hayashi), Urara Awata ...
# 2658  Gloria Swanson (Marion Donnell), Robert Ames (...
# 5238  Antonio Flores (Antonio), Rosario Flores (Rosa...
#
#                                             description release_date
# 2681  a father and son must team up to save christma...   2014-12-05
# 5908  a group of lifeguards attempt to kill an atomi...   2016-07-24
# 9559  living in an old tokyo district, kenichi works...   1995-01-14
# 2658  a stenographer who works for a lawyer falls in...   1929-11-11
# 5238  josé is an unemployed 18-year-old living in a ...   1982-10-25

# %% [markdown]
# ### Using translate

# %%
# take less time

def remove_puctuations2(word):
    return word.translate(str.maketrans("","",puctuations))

# %%
df['description'][1]
# Out:
# 'having found the safety of the greenland bunker after the comet clarke decimated the earth, the garrity family must now risk everything to embark on a perilous journey across the wasteland of europe to find a new home.'

# %%
df['description'] = df['description'].apply(remove_puctuations2)

# %% [markdown]
# ## 5. Chat Word Treatment (Slang Expansion)
#
# eg: ASAP -> As Soon As Possible

# %%
chat_words_dict = {}
with open("data/english_chat_words.txt","r") as file:
    for f in file.readlines():
        chat_words_dict[f.split("->")[0].strip()] = f.split("->")[1].strip()

    # chat_words.append(file.read().split("->"))

# %%
def remove_chatwords(sentence):
    result = str(sentence)
    for word in sentence.split(" "):
        if word.upper() in chat_words_dict:
            print(word)
            print(chat_words_dict[word.upper()])
            result = result.replace(word, chat_words_dict[word.upper()])
    return result

# %%
remove_chatwords("TBH I have to go ASAP to office")
# Out:
# TBH
# To Be Honest
# ASAP
# As Soon As Possible
# 'To Be Honest I have to go As Soon As Possible to office'

# %%
df['description'].apply(remove_chatwords)
# Out:
# tba
# To Be Announced
# tba
# To Be Announced
# jk
# Just Kidding
# tba
# To Be Announced
# jk
# Just Kidding
# tba
# To Be Announced
# y
# Why
# tba
# To Be Announced
# tba
# To Be Announced
# aka
# Also Known As
# aka
# Also Known As
# ty
# Thank You
# ty
# Thank You
# ty
# Thank You
# tia
# Thanks In Advance
# diy
# Do It Yourself
# diy
# Do It Yourself
# aka
# Also Known As
# tba
# To Be Announced
# ty
# Thank You
# ooo
# Out Of Office
# aka
# Also Known As
# tia
# Thanks In Advance
# yt
# YouTube
# yt
# YouTube
# aka
# Also Known As
# aka
# Also Known As
# aka
# Also Known As
# aka
# Also Known As
# aka
# Also Known As
# aka
# Also Known As
# ty
# Thank You
# sos
# Save Our Souls (Help)
# op
# Original Poster
# u
# You
# aka
# Also Known As
# 0       estranged halfbrothers jonny and james reunite...
# 1       having found the safety of the greenland bunke...
# 2       after cracking the biggest case in zootopias h...
# 3       macau police brings the tracking expert police...
# 4       a group of friends facing midlife crises head ...
#                               ...
# 9994    during world war ii captain cassidy and his cr...
# 9996    after her car is towed and she is left with a ...
# 9997    the woman lets herself go so she can assuage h...
# 9998    set in the sleepy town of bawley point on the ...
# 9999    set in turnofthecentury new england this music...
# Name: description, Length: 8876, dtype: str

# %%
df['description'] = df['description'].apply(remove_chatwords)
# Out:
# tba
# To Be Announced
# tba
# To Be Announced
# jk
# Just Kidding
# tba
# To Be Announced
# jk
# Just Kidding
# tba
# To Be Announced
# y
# Why
# tba
# To Be Announced
# tba
# To Be Announced
# aka
# Also Known As
# aka
# Also Known As
# ty
# Thank You
# ty
# Thank You
# ty
# Thank You
# tia
# Thanks In Advance
# diy
# Do It Yourself
# diy
# Do It Yourself
# aka
# Also Known As
# tba
# To Be Announced
# ty
# Thank You
# ooo
# Out Of Office
# aka
# Also Known As
# tia
# Thanks In Advance
# yt
# YouTube
# yt
# YouTube
# aka
# Also Known As
# aka
# Also Known As
# aka
# Also Known As
# aka
# Also Known As
# aka
# Also Known As
# aka
# Also Known As
# ty
# Thank You
# sos
# Save Our Souls (Help)
# op
# Original Poster
# u
# You
# aka
# Also Known As

# %% [markdown]
# ## Removing stopwords

# %%
import nltk
nltk.download('stopwords', download_dir='/home/rathan-r-nayak/Rathan/Machine Learning/machine-leaning/NLP/TextPreprocessing/data')
from nltk.corpus import stopwords
nltk.data.path.append(
    '/home/rathan-r-nayak/Rathan/Machine Learning/machine-leaning/NLP/TextPreprocessing/data'
)
# Out:
# [nltk_data] Downloading package stopwords to /home/rathan-r-
# [nltk_data]     nayak/Rathan/Machine Learning/machine-
# [nltk_data]     leaning/NLP/TextPreprocessing/data...
# [nltk_data]   Package stopwords is already up-to-date!

# %%
stopwords.words('english')
# Out:
# ['a',
#  'about',
#  'above',
#  'after',
#  'again',
#  'against',
#  'ain',
#  'all',
#  'am',
#  'an',
#  'and',
#  'any',
#  'are',
#  'aren',
#  "aren't",
#  'as',
#  'at',
#  'be',
#  'because',
#  'been',
#  'before',
#  'being',
#  'below',
#  'between',
#  'both',
#  'but',
#  'by',
#  'can',
#  'couldn',
#  "couldn't",
#  'd',
#  'did',
#  'didn',
#  "didn't",
#  'do',
#  'does',
#  'doesn',
#  "doesn't",
#  'doing',
#  'don',
#  "don't",
#  'down',
#  'during',
#  'each',
#  'few',
#  'for',
#  'from',
#  'further',
#  'had',
#  'hadn',
#  "hadn't",
#  'has',
#  'hasn',
#  "hasn't",
#  'have',
#  'haven',
#  "haven't",
#  'having',
#  'he',
#  "he'd",
#  "he'll",
#  'her',
#  'here',
#  'hers',
#  'herself',
#  "he's",
#  'him',
#  'himself',
#  'his',
#  'how',
#  'i',
#  "i'd",
#  'if',
#  "i'll",
#  "i'm",
#  'in',
#  'into',
#  'is',
#  'isn',
#  "isn't",
#  'it',
#  "it'd",
#  "it'll",
#  "it's",
#  'its',
#  'itself',
#  "i've",
#  'just',
#  'll',
#  'm',
#  'ma',
#  'me',
#  'mightn',
#  "mightn't",
#  'more',
#  'most',
#  'mustn',
#  "mustn't",
#  'my',
#  'myself',
#  'needn',
#  "needn't",
#  'no',
#  'nor',
#  'not',
#  'now',
#  'o',
#  'of',
#  'off',
#  'on',
#  'once',
#  'only',
#  'or',
#  'other',
#  'our',
#  'ours',
#  'ourselves',
#  'out',
#  'over',
#  'own',
#  're',
#  's',
#  'same',
#  'shan',
#  "shan't",
#  'she',
#  "she'd",
#  "she'll",
#  "she's",
#  'should',
#  'shouldn',
#  "shouldn't",
#  "should've",
#  'so',
#  'some',
#  'such',
#  't',
#  'than',
#  'that',
#  "that'll",
#  'the',
#  'their',
#  'theirs',
#  'them',
#  'themselves',
#  'then',
#  'there',
#  'these',
#  'they',
#  "they'd",
#  "they'll",
#  "they're",
#  "they've",
#  'this',
#  'those',
#  'through',
#  'to',
#  'too',
#  'under',
#  'until',
#  'up',
#  've',
#  'very',
#  'was',
#  'wasn',
#  "wasn't",
#  'we',
#  "we'd",
#  "we'll",
#  "we're",
#  'were',
#  'weren',
#  "weren't",
#  "we've",
#  'what',
#  'when',
#  'where',
#  'which',
#  'while',
#  'who',
#  'whom',
#  'why',
#  'will',
#  'with',
#  'won',
#  "won't",
#  'wouldn',
#  "wouldn't",
#  'y',
#  'you',
#  "you'd",
#  "you'll",
#  'your',
#  "you're",
#  'yours',
#  'yourself',
#  'yourselves',
#  "you've"]

# %%
def remove_stopwords(sentence):
    li = []

    for word in sentence.split(" "):
        if word not in stopwords.words('english'):
            li.append(word)
    return " ".join(li)

# %%
remove_stopwords("I was in office for long time")
# Out:
# 'I office long time'

# %%
df['description'].apply(remove_stopwords)
# Out:
# 0       estranged halfbrothers jonny james reunite fat...
# 1       found safety greenland bunker comet clarke dec...
# 2       cracking biggest case zootopias history rookie...
# 3       macau police brings tracking expert police off...
# 4       group friends facing midlife crises head rainf...
#                               ...
# 9994    world war ii captain cassidy crew submariners ...
# 9996    car towed left shocking 21634 tow bill unhouse...
# 9997    woman lets go assuage erotic affliction provoc...
# 9998    set sleepy town bawley point nsw south coast b...
# 9999    set turnofthecentury new england musical tells...
# Name: description, Length: 8876, dtype: str

# %%
df['description'] = df['description'].apply(remove_stopwords)

# %% [markdown]
# ## Handling Emoji

# %%
import emoji

# %%
word = "I love NLP 🤖🔥"

emoji.replace_emoji(word, replace="")
# Out:
# 'I love NLP '

# %%
df['description'] = df['description'].apply(lambda x: emoji.replace_emoji(x, replace="").strip())

# %% [markdown]
# ## Spelling Correction

# %%
from textblob import TextBlob

# %%
incorrect_txt = "I wass walkisg to an offce"

text_blob = TextBlob(incorrect_txt)

text_blob.correct().string
# Out:
# 'I was walking to an office'

# %%
def fix_spelling(sentence):
    text_blob = TextBlob(sentence)
    return text_blob.correct().string

# %%
df['description'] = df['description'].apply(fix_spelling)
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[186], line 1
# ----> 1 df['description'] = df['description'].apply(fix_spelling)
#
# File ~/Rathan/Machine Learning/machine-leaning/NLP/nlp_env/lib/python3.12/site-packages/pandas/core/series.py:5084, in Series.apply(self, func, args, by_row, **kwargs)
#    4960 def apply(
#    4961     self,
#    4962     func: AggFuncType,
#    (...)   4966     **kwargs,
#    4967 ) -> DataFrame | Series:
#    4968     """
#    4969     Invoke function on values of Series.
#    4970
#    (...)   5076     dtype: float64
#    5077     """
#    5078     return SeriesApply(
#    5079         self,
#    5080         func,
#    5081         by_row=by_row,
#    5082         args=args,
#    5083         kwargs=kwargs,
# -> 5084     ).apply()
#
# File ~/Rathan/Machine Learning/machine-leaning/NLP/nlp_env/lib/python3.12/site-packages/pandas/core/apply.py:1520, in SeriesApply.apply(self)
#    1517     return self.apply_compat()
#    1519 # self.func is Callable
# -> 1520 return self.apply_standard()
#
# File ~/Rathan/Machine Learning/machine-leaning/NLP/nlp_env/lib/python3.12/site-packages/pandas/core/apply.py:1578, in SeriesApply.apply_standard(self)
#    1576 else:
#    1577     curried = func
# -> 1578 mapped = obj._map_values(mapper=curried)
#    1580 if len(mapped) and isinstance(mapped[0], ABCSeries):
#    1581     # GH#43986 Need to do list(mapped) in order to get treated as nested
#    1582     #  See also GH#25959 regarding EA support
#    1583     return obj._constructor_expanddim(list(mapped), index=obj.index)
#
# File ~/Rathan/Machine Learning/machine-leaning/NLP/nlp_env/lib/python3.12/site-packages/pandas/core/base.py:1020, in IndexOpsMixin._map_values(self, mapper, na_action)
#    1017 arr = self._values
#    1019 if isinstance(arr, ExtensionArray):
# -> 1020     return arr.map(mapper, na_action=na_action)
#    1022 return algorithms.map_array(arr, mapper, na_action=na_action)
#
# File ~/Rathan/Machine Learning/machine-leaning/NLP/nlp_env/lib/python3.12/site-packages/pandas/core/arrays/base.py:2692, in ExtensionArray.map(self, mapper, na_action)
#    2672 def map(self, mapper, na_action: Literal["ignore"] | None = None):
#    2673     """
#    2674     Map values using an input mapping or function.
#    2675
#    (...)   2690         a MultiIndex will be returned.
#    2691     """
# -> 2692     return map_array(self, mapper, na_action=na_action)
#
# File ~/Rathan/Machine Learning/machine-leaning/NLP/nlp_env/lib/python3.12/site-packages/pandas/core/algorithms.py:1710, in map_array(arr, mapper, na_action)
#    1708 values = arr.astype(object, copy=False)
#    1709 if na_action is None:
# -> 1710     return lib.map_infer(values, mapper)
#    1711 else:
#    1712     return lib.map_infer_mask(values, mapper, mask=isna(values).view(np.uint8))
#
# File pandas/_libs/lib.pyx:3071, in pandas._libs.lib.map_infer()
#
# Cell In[184], line 3, in fix_spelling(sentence)
#       1 def fix_spelling(sentence):
#       2     text_blob = TextBlob(sentence)
# ----> 3     return text_blob.correct().string
#
# File ~/Rathan/Machine Learning/machine-leaning/NLP/nlp_env/lib/python3.12/site-packages/textblob/blob.py:555, in BaseBlob.correct(self)
#     553 tokens = nltk.tokenize.regexp_tokenize(self.raw, r"\w+|[^\w\s]|\s")
#     554 corrected = (Word(w).correct() for w in tokens)
# --> 555 ret = "".join(corrected)
#     556 return self.__class__(ret)
#
# File ~/Rathan/Machine Learning/machine-leaning/NLP/nlp_env/lib/python3.12/site-packages/textblob/blob.py:554, in <genexpr>(.0)
#     552 # regex matches: word or punctuation or whitespace
#     553 tokens = nltk.tokenize.regexp_tokenize(self.raw, r"\w+|[^\w\s]|\s")
# --> 554 corrected = (Word(w).correct() for w in tokens)
#     555 ret = "".join(corrected)
#     556 return self.__class__(ret)
#
# File ~/Rathan/Machine Learning/machine-leaning/NLP/nlp_env/lib/python3.12/site-packages/textblob/blob.py:115, in Word.correct(self)
#     109 def correct(self):
#     110     """Correct the spelling of the word. Returns the word with the highest
#     111     confidence using the spelling corrector.
#     112
#     113     .. versionadded:: 0.6.0
#     114     """
# --> 115     return Word(self.spellcheck()[0][0])
#
# File ~/Rathan/Machine Learning/machine-leaning/NLP/nlp_env/lib/python3.12/site-packages/textblob/blob.py:107, in Word.spellcheck(self)
#      98 def spellcheck(self):
#      99     """Return a list of (word, confidence) tuples of spelling corrections.
#     100
#     101     Based on: Peter Norvig, "How to Write a Spelling Corrector"
#    (...)    105     .. versionadded:: 0.6.0
#     106     """
# --> 107     return suggest(self.string)
#
# File ~/Rathan/Machine Learning/machine-leaning/NLP/nlp_env/lib/python3.12/site-packages/textblob/en/__init__.py:118, in suggest(w)
#     116 def suggest(w):
#     117     """Returns a list of (word, confidence)-tuples of spelling corrections."""
# --> 118     return spelling.suggest(w)
#
# File ~/Rathan/Machine Learning/machine-leaning/NLP/nlp_env/lib/python3.12/site-packages/textblob/_text.py:1692, in Spelling.suggest(self, w)
#    1687 if w.replace(".", "").isdigit():
#    1688     return [(w, 1.0)]  # 1.5
#    1689 candidates = (
#    1690     self._known([w])
#    1691     or self._known(self._edit1(w))
# -> 1692     or self._known(self._edit2(w))
#    1693     or [w]
#    1694 )
#    1695 candidates = [(self.get(c, 0.0), c) for c in candidates]
#    1696 s = float(sum(p for p, word in candidates) or 1)
#
# File ~/Rathan/Machine Learning/machine-leaning/NLP/nlp_env/lib/python3.12/site-packages/textblob/_text.py:1667, in Spelling._edit2(self, w)
#    1664 """Returns a set of words with edit distance 2 from the given word"""
#    1665 # Of all spelling errors, 99% is covered by edit distance 2.
#    1666 # Only keep candidates that are actually known words (20% speedup).
# -> 1667 return set(e2 for e1 in self._edit1(w) for e2 in self._edit1(e1) if e2 in self)
#
# File ~/Rathan/Machine Learning/machine-leaning/NLP/nlp_env/lib/python3.12/site-packages/textblob/_text.py:1667, in <genexpr>(.0)
#    1664 """Returns a set of words with edit distance 2 from the given word"""
#    1665 # Of all spelling errors, 99% is covered by edit distance 2.
#    1666 # Only keep candidates that are actually known words (20% speedup).
# -> 1667 return set(e2 for e1 in self._edit1(w) for e2 in self._edit1(e1) if e2 in self)
#
# KeyboardInterrupt:

# %% [markdown]
# ## Tokenization

# %% [markdown]
# ### NLTK

# %%
from nltk.tokenize import word_tokenize

# %%
word_tokenize("Dr. Smith paid Rs. 20 for Ph.D. books.")
# Out:
# ['Dr.', 'Smith', 'paid', 'Rs', '.', '20', 'for', 'Ph.D.', 'books', '.']

# %%
from nltk.tokenize import sent_tokenize

# %%
sent_tokenize("Dr. Smith paid Rs. 20 for Ph.D. books.")
# Out:
# ['Dr. Smith paid Rs.', '20 for Ph.D. books.']

# %% [markdown]
# ### Spacy

# %%
import spacy

# %%
nlp = spacy.load("en_core_web_sm")

doc = nlp("Dr. Smith paid Rs. 20 for Ph.D. books.")

# %%
for text in doc:
    print(text)
# Out:
# Dr.
# Smith
# paid
# Rs
# .
# 20
# for
# Ph.D.
# books
# .

# %% [markdown]
# ## Stemming

# %%
from nltk.stem import PorterStemmer

# %%
ps = PorterStemmer()

words = ["running", "played", "happiness", "daily"]

for word in words:
    print(ps.stem(word))
# Out:
# run
# play
# happi
# daili

# %% [markdown]
# ## Lemmatization

# %%
from nltk.stem import WordNetLemmatizer
from nltk.corpus import wordnet
nltk.download('wordnet', download_dir='/home/rathan-r-nayak/Rathan/Machine Learning/machine-leaning/NLP/TextPreprocessing/data')
nltk.data.path.append('/home/rathan-r-nayak/Rathan/Machine Learning/machine-leaning/NLP/TextPreprocessing/data')

lemmatizer = WordNetLemmatizer()

for word in words:
    print(lemmatizer.lemmatize(word=word, pos=wordnet.VERB))
# Out:
# [nltk_data] Downloading package wordnet to /home/rathan-r-
# [nltk_data]     nayak/Rathan/Machine Learning/machine-
# [nltk_data]     leaning/NLP/TextPreprocessing/data...
# run
# play
# happiness
# daily
